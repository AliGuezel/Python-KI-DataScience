# %% [markdown]
# #### Erzeuge folgendes Dataframe
#
#     X   Y   Z
# 0  78  84  86
# 1  85  94  97
# 2  96  89  96

# %%
import pandas as pd

df = #?
print(df)
# Out:
#     X   Y   Z
# 0  78  84  86
# 1  85  94  97
# 2  96  89  96

# %% [markdown]
# #### Erzeuge aus folgenden Daten ein Dataframe
#
# exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
# 'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
# 'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
# 'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
#
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
import pandas as pd
import numpy as np

exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df = #?

print(df)
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %% [markdown]
# #### Gib die ersten drei Zeilen des vorangegangenen Dataframe aus

# %%
print(df.<platzhalte>)
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes

# %% [markdown]
# #### Lade die Daten aus data/weather.csv in ein Dataframe und gib sie aus

# %%
import pandas as pd

df = #?

print(df)
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65      56.0
# 1  5/2/2017  new york           66      58.0
# 2  5/3/2017  new york           68      60.0
# 3  5/1/2017    mumbai           75      80.0
# 4  5/2/2017    mumbai           78      83.0
# 5  5/3/2017    mumbai           82      85.0
# 6  6/3/2017    mumbai           82       NaN
# 7  5/1/2017   beijing           80      26.0
# 8  5/2/2017   beijing           77      30.0
# 9  5/3/2017   beijing           79      35.0

# %% [markdown]
# #### Berechne aus den Daten ('data/weather.csv') die Durchschnitts-"humidity" ,maximale Humidity `max()`,minimale Humidity `min()` mittels "grouping"

# %%
# Out:
# city
# beijing     30.333333
# mumbai      82.666667
# new york    58.000000
# Name: humidity, dtype: float64
# city
# beijing     26.0
# mumbai      80.0
# new york    56.0
# Name: humidity, dtype: float64
# city
# beijing     35.0
# mumbai      85.0
# new york    60.0
# Name: humidity, dtype: float64

# %% [markdown]
# #### Gib die Zeilen mit Index 3 und 5 aus der folgenden Series mittels loc und iloc aus

# %%
data = pd.Series(['a', 'b', 'c','d'], index=[1, 3, 5, 7])
print(data)
# Out:
# 1    a
# 3    b
# 5    c
# 7    d
# dtype: object
# 3    b
# 5    c
# dtype: object
# 3    b
# 5    c
# dtype: object

# %% [markdown]
# #### Gib den Datensatz mit der maximalen Durchschnittstemperatur aus. Verwende dafür die Funktion .idxmax() (Advanced)

# %%
import pandas as pd

df = pd.read_csv('data/DWD.csv',sep=';')

#code hier
