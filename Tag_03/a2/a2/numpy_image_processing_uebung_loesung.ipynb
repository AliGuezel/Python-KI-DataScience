# %% [markdown]
# # Übungs Aufgaben:
#
# 1. Einen 10 Pixel breiten weißen Rand um das Bild Zeichnen
# 2. Das Bild jeweils horizontal und vertikal spiegeln
# 3. Ein zweites Bild einfügen
# 4. Eigenen Recherche: Füge zwei gleiche Bilder aneinander mit der Funktion `concatenate`
# (<https://numpy.org/doc/stable/reference/generated/numpy.concatenate.html>)
# 5. rotiert das Bild  um 90 Grad und benutze dabei die Funktion numpy.rot90()
# # (<https://numpy.org/doc/stable/reference/generated/numpy.rot90.html>)

# %%
# 1.

from PIL import Image #  "Python Image Library" Pillow Library https://python-pillow.org/
import numpy as np 

im = np.array(Image.open('img/tiger.jpg')) #
print(type(im))
print(im.dtype)
print(im.shape)

#print(im[0,0])
# Rotanteil R, der Grünanteil G und der Blauanteil B die Farbe beschreiben: Farbe = (R, G, B) 
# [255,255,255] = Weiß, [0,0,0] = Schwarz

im[:10,:] = [255,255,255]
im[-10:,:] = [255,255,255]
im[:,-10:] = [255,255,255]
im[:,:10] = [255,255,255]

# Bild speichern


pil_img = Image.fromarray(im)
#print(pil_img.mode)
# RGB
pil_img.save('img/out/tiger.jpg')

# Bild in jupyter-notebook ausgeben
from IPython.display import Image
Image(filename='img/out/tiger.jpg')
# Out:
# <class 'numpy.ndarray'>
# uint8
# (427, 640, 3)

# %%
# 2.

from PIL import Image #  "Python Image Library" Pillow Library https://python-pillow.org/
import numpy as np 

im = np.array(Image.open('img/tiger.jpg')) #
print(type(im))
print(im.dtype)
print(im.shape)

#print(im[0,0])
# Rotanteil R, der Grünanteil G und der Blauanteil B die Farbe beschreiben: Farbe = (R, G, B) 
# [255,255,255] = Weiß, [0,0,0] = Schwarz

# horizontal und vertikal spiegeln
#im = im[::-1,:]
im = im[::,::-1]

# Bild speichern


pil_img = Image.fromarray(im)
#print(pil_img.mode)
# RGB
pil_img.save('img/out/tiger.jpg')

# Bild in jupyter-notebook ausgeben
from IPython.display import Image
Image(filename='img/out/tiger.jpg')
# Out:
# <class 'numpy.ndarray'>
# uint8
# (427, 640, 3)

# %%
# 4. 4. Ein zweites Bild einfügen

from PIL import Image #  "Python Image Library" Pillow Library https://python-pillow.org/
import numpy as np 

im = np.array(Image.open('img/tiger.jpg')) #
print(type(im))
print(im.dtype)
print(im.shape)

im2 = np.array(Image.open('img/schmetterling.jpg')) #

print(type(im2))
print(im2.dtype)
print(im2.shape)

xpos = 130
ypos = 40

#im[xpos:363+xpos,ypos:480+ypos] = im2 # (im2 = im2[::2,::2])
im[xpos:im2.shape[0]+xpos,ypos:im2.shape[1]+ypos] = im2


#print(im[0,0])
# Rotanteil R, der Grünanteil G und der Blauanteil B die Farbe beschreiben: Farbe = (R, G, B) 
# [255,255,255] = Weiß, [0,0,0] = Schwarz


# Bild speichern


pil_img = Image.fromarray(im)
#print(pil_img.mode)
# RGB
pil_img.save('img/out/tiger.jpg')

# Bild in jupyter-notebook ausgeben
from IPython.display import Image
Image(filename='img/out/tiger.jpg')
# Out:
# <class 'numpy.ndarray'>
# uint8
# (427, 640, 3)
# <class 'numpy.ndarray'>
# uint8
# (227, 300, 3)

# %% [markdown]
# 5. Eigen Recherche: Füge zwei gleiche Bilder aneinander mit der Funktion `concatenate`
# (<https://numpy.org/doc/stable/reference/generated/numpy.concatenate.html>)

# %%
from PIL import Image #  "Python Image Library" Pillow Library https://python-pillow.org/
import numpy as np 

im = np.array(Image.open('img/tiger.jpg')) #
print(type(im))
print(im.dtype)
print(im.shape)

#print(im[0,0])
# Rotanteil R, der Grünanteil G und der Blauanteil B die Farbe beschreiben: Farbe = (R, G, B) 
# [255,255,255] = Weiß, [0,0,0] = Schwarz


im = np.concatenate((im,im), axis=0)
#im = np.concatenate((im,im), axis=1)



# Bild speichern
pil_img = Image.fromarray(im)
#print(pil_img.mode)
# RGB
pil_img.save('img/out/tiger.jpg')

# Bild in jupyter-notebook ausgeben
from IPython.display import Image
Image(filename='img/out/tiger.jpg')
# Out:
# <class 'numpy.ndarray'>
# uint8
# (427, 640, 3)

# %% [markdown]
# 6. rotiert das Bild  um 90 Grad und benutze dabei die Funktion numpy.rot90()
# (<https://numpy.org/doc/stable/reference/generated/numpy.rot90.html>)

# %%
from PIL import Image #  "Python Image Library" Pillow Library https://python-pillow.org/
import numpy as np 

im = np.array(Image.open('img/tiger.jpg')) #
print(type(im))
print(im.dtype)
print(im.shape)

#print(im[0,0])
# Rotanteil R, der Grünanteil G und der Blauanteil B die Farbe beschreiben: Farbe = (R, G, B) 
# [255,255,255] = Weiß, [0,0,0] = Schwarz

im = np.rot90(im)
#im = np.rot90(im)
im = np.rot90(im,k=3)


# Bild speichern
pil_img = Image.fromarray(im)
#print(pil_img.mode)
# RGB
pil_img.save('img/out/tiger.jpg')

# Bild in jupyter-notebook ausgeben
from IPython.display import Image
Image(filename='img/out/tiger.jpg')
# Out:
# <class 'numpy.ndarray'>
# uint8
# (427, 640, 3)
