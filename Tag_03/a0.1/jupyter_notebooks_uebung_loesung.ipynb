# %% [markdown]
# ### Übung
#
#
# * füge ein eigenes Bild ein
# * entwickle eine LaTex-Darstellung für die pq-Formel
#     ![pqformel](img/pq-formel.png)
#
# * entwickle eine LaTex-Darstellung für die Formel des Arithmetischen Mittelwert:
#
#     ![Formel Arithmetisches Mittel](img/arith_mittel.png)
#
#     https://de.wikipedia.org/wiki/Arithmetisches_Mittel
#
# * Erstelle folgende Table:
#
#     ![tabelle](img/table.png)

# %% [markdown]
# ### Lösung

# %% [markdown]
# * ![schmetterling](img/schmetterling.jpg)
#
# * $x_{1/2}$ = - $\frac{p}{2}$  $\pm$  	$\sqrt{(\frac{p}{q})^{2}  -q}$
#
# * x := ($x_{1}$ + $x_{2}$ + .. + $x_{n}$) = $\frac{1}{n}$ $\sum_{i=1}^{n} x_i$
#
# * Tabelle:
#
#
# | | Apples | Bananas |
# |:-----------:|:---------|:-------|
# | 0 | 30 | 21 |
