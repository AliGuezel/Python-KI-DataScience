# %% [markdown]
# #### Gegeben ist der Folgen Python-Code
#
# * erzeuge eine neu Python-Environment im gleichen Ordner wie diese Datein, aktiviere diese und installiere die benötigten Packages: pip install yfinance numpy matplot
#
# yfinance steht für Yahoo-Finance. Es ist eine API um Börsenkurse und Informationen über Kurse und Unternehmen abzufragen
#
# * führe den Pyhton-Code aus
#
# Die Variable stock_data ist ein Pandas-Dataframe welche mit den entspechenden Methoden weiterverarbeitet werden kann
#
# * zeichne einen Graph aus dem Schlusskurs, also der Spalte "Close" mittels "plot()"
#
# * gib den Tages-Datensatz aus mit dem höchsten "Volume"
#
# * gib den Tages-Datensatz aus mit dem höchsten Handelsspanne (maximum von High - Low)
# Hinweis: Erzeuge eine neue Spalte für die Handelsspanne

# %%
# pip install yfinance numpy matplot

import numpy as np
import yfinance as yf
import matplotlib

def getStock(symbol : str) -> yf.Ticker:
    if symbol:
        try:
            stock = yf.Ticker(symbol)
        except Exception as e: 
            print(e)

    return stock

def getStockDataFromSymbol(symbol: str,period = '3y',interval= '1d'):  
    stock = getStock(symbol)

    return stock.history(period, interval)


symbol = "BTC-USD" # Ander Ticker-Symbole sind möglich zb. MSFT, GOOG, .. (vgl. https://finance.yahoo.com/)
#symbol = "GOOG"

stock_data = getStockDataFromSymbol(symbol,interval= '1d')
print(stock_data)
print(type(stock_data))
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2020-06-22 00:00:00-04:00   71.449997   72.637497   71.160500   72.593002
# 2020-06-23 00:00:00-04:00   72.781998   73.797050   72.262001   73.220497
# 2020-06-24 00:00:00-04:00   73.075500   73.771004   71.487503   71.598503
# 2020-06-25 00:00:00-04:00   71.495003   72.144997   71.000000   72.066498
# 2020-06-26 00:00:00-04:00   71.569504   71.672501   67.599503   67.995003
# ...                               ...         ...         ...         ...
# 2023-06-13 00:00:00-04:00  125.650002  125.860001  123.845001  124.430000
# 2023-06-14 00:00:00-04:00  123.800003  124.790001  122.160004  124.379997
# 2023-06-15 00:00:00-04:00  123.879997  126.160004  123.139999  125.790001
# 2023-06-16 00:00:00-04:00  126.699997  126.699997  123.790001  124.059998
# 2023-06-20 00:00:00-04:00  123.535004  125.175003  122.830002  123.915001
#
#                              Volume  Dividends  Stock Splits
# Date
# 2020-06-22 00:00:00-04:00  30848000        0.0           0.0
# 2020-06-23 00:00:00-04:00  28596000        0.0           0.0
# 2020-06-24 00:00:00-04:00  35120000        0.0           0.0
# 2020-06-25 00:00:00-04:00  24610000        0.0           0.0
# 2020-06-26 00:00:00-04:00  85354000        0.0           0.0
# ...                             ...        ...           ...
# 2023-06-13 00:00:00-04:00  19287700        0.0           0.0
# 2023-06-14 00:00:00-04:00  24659600        0.0           0.0
# 2023-06-15 00:00:00-04:00  24517100        0.0           0.0
# 2023-06-16 00:00:00-04:00  56686800        0.0           0.0
# 2023-06-20 00:00:00-04:00  17448413        0.0           0.0
#
# [754 rows x 7 columns]
# <class 'pandas.core.frame.DataFrame'>

# %%
# plot

# %%
# max Volume

# %%
# max "Range" (Handelspanne)
